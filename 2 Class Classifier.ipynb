# %% [markdown]
# # 2 Class Classifier

# %%
import math
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp

# %%
dataset = pd.read_csv('data.csv')

# %% [markdown]
# ### Method 1
# Gradient boosted model.
# Create features based on mainly on std div?

# %%
plt.plot(dataset[:20 * 1000])

# %%
plt.plot(dataset[: 60 * 24])
plt.plot(np.repeat(1, 60 * 24))

plt.legend(['1 day', 'zero'])

# %% [markdown]
# Should we be predicting the nighttime data? <br>
# It has non-zero values due to subtracting the trend?

# %%
plt.plot(np.linspace(0, 1, 60 * 24) ,dataset[60 * 24 : 2 * 60 * 24])
plt.plot(np.linspace(0, 1, 60 * 24), np.repeat(1, 60 * 24))

# %%
plt.plot(np.linspace(0, 1, 60 * 24) ,dataset[2 * 60 * 24 : 3 * 60 * 24])
plt.plot(np.linspace(0, 1, 60 * 24), np.repeat(1, 60 * 24))

# %% [markdown]
# ## Night centered

# %%
plt.plot(np.linspace(0, 1, 60 * 24) ,dataset[int(2 * 60 * 24 + 0.5 * 60 * 24) : int(3 * 60 * 24 + 0.5 * 60 * 24)])
plt.plot(np.linspace(0, 1, 60 * 24), np.repeat(1, 60 * 24))

# %%
i = 7
plt.plot(np.linspace(0, 1, 60 * 24) ,dataset[int(i * 60 * 24 + 0.5 * 60 * 24) : int((i + 1) * 60 * 24 + 0.5 * 60 * 24)])
plt.plot(np.linspace(0, 1, 60 * 24), np.repeat(1, 60 * 24))

# %% [markdown]
# ## Data with nights removed

# %%
for i in range(0, 7):
    plt.plot(np.linspace(i, i + 1, 0.5 * 60 * 24), dataset[int(i * 60 * 24 + 0.25 * 60 * 24) : int(i * 60 * 24 + 0.75 * 60 * 24)])
    
    plt.title('Daytime only data')
    plt.xlabel('Day')
    plt.ylabel('Irregular component (KW)')
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %% [markdown]
# #### Is the y axis label here correct?

# %% [markdown]
# - Would need to re-calculate H for the new dataset.
# - Halves dataset size.
# - Likely reduce prediction accuracy and H?

# %% [markdown]
# In the battery application - What is the charging and discharging cycle during this time? it is still signficant. Considering the entire daily profile.

# %% [markdown]
# This is just the PV data generation.

# %% [markdown]
# ## Nightly data

# %%
for i in range(0, 7):
    plt.plot(np.linspace(i, i + 1, 0.5 * 60 * 24), dataset[int(i * 60 * 24 + 0.75 * 60 * 24) : int(i * 60 * 24 + 1.25 * 60 * 24)])

plt.title('Nighttime only data')
plt.xlabel('Day')
plt.ylabel('Irregular component (KW)')
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# Text(0,0.5,'Irregular component (KW)')

# %% [markdown]
# Biggest problem is that: PV has daily seasonality.
