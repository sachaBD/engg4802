# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from AutoValidator.model_tester import ModelTester
from utils.progress import ProgressBar
progress = ProgressBar()

# %%
data = pd.read_csv('data/filter_data.csv')
hurst_estimates = pd.read_csv('data/hurst_estimates.csv')
hurst_estimates.set_index('Unnamed: 0', inplace=True)

# %%
data = data['window_1_0']

# %%
diff_data = data[1:].values - data[:-1].values

# %%
data = data[1:].values

# %%
diff_data
# Out:
# array([-0.074, -0.073, -0.074, ...,  0.082,  0.082,  0.082])

# %%
plt.plot(diff_data)

# %%
def xy_backtest(X, y, start, step_size):
    step = step_size
    start = int(start * len(X))
    splits = np.arange(start, len(X), step)
    
    results = []
    
    for test_start, test_end in zip(splits[:-1], splits[1:]):
        results.append((X[:test_start], X[test_start:test_end], y[:test_start], y[test_start:test_end]))
        
    return results

# %%
data.shape, diff_data.shape
# Out:
# ((86257,), (86257,))

# %%
horizon = 5

col = diff_data.flatten()
indexer = np.arange(horizon)[None, :] + np.arange(len(diff_data) - 2 * horizon)[:, None]
X = data[indexer]
y = diff_data[np.arange(horizon, len(diff_data) - horizon)]

# X, y = X[:40000], y[:40000]

# %%
X.shape, y.shape
# Out:
# ((86247, 5), (86247,))

# %%
from lightgbm import LGBMRegressor

# %%
split = int(0.8 * len(X))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# %%
model = LGBMRegressor(n_estimators=10, num_leaves=8)

model.fit(X_train, y_train)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#        importance_type='split', learning_rate=0.1, max_depth=-1,
#        min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#        n_estimators=10, n_jobs=-1, num_leaves=8, objective=None,
#        random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_train.shape, X_train.shape
# Out:
# ((68997,), (68997, 5))

# %%
pred = model.predict(X_train)

print(mean_absolute_error(y_train, pred))
print(pred.shape, y_train.shape)

# %matplotlib notebook
plt.plot(y_train)
plt.plot(pred)
# Out:
# 27.848377519687677
# (68997,) (68997,)
# <img src="data:image/png;base64,..." width="640">

# %%
pred = model.predict(X_test)

print(mean_absolute_error(y_test, pred))

# %matplotlib notebook
plt.plot(y_test)
plt.plot(pred)
# Out:
# 26.609807389594735
# <img src="data:image/png;base64,..." width="640">

# %%
pred = np.repeat(X_test.mean(), len(y_test))

print(mean_absolute_error(y_test, pred))

# %matplotlib notebook
plt.plot(y_test)
plt.plot(pred)
# Out:
# 27.16027172613801
# <img src="data:image/png;base64,..." width="640">
