# %%
import pandas as pd
import os

# %%
results = {}

for file in os.listdir('results'):
    print(file)
    if file.endswith('results.csv'):
        results[file] = pd.read_csv('results/' + file)
# Out:
# baseline_five_minutes_results.cssv
# five_minute_boosted_tree_models
# five_minute_boosted_tree_results.csv
# five_minute_exponential_moving_average_results.csv
# five_minute_krr_results.csv
# one_minute_baseline_results.csv
# one_minute_boosted_tree_models
# one_minute_boosted_tree_results.csv
# one_minute_exponential_moving_average_results.csv
# sixty_minute_baseline_results.csv
# sixty_minute_exponential_moving_average_results.csv

# %%
results['five_minute_krr_results.csv']
# Out:
#       Unnamed: 0  \
# 0     window_1_0
# 1     window_1_1
# 2     window_1_2
# 3     window_1_3
# 4     window_1_4
# 5     window_1_5
# 6     window_1_6
# 7     window_1_7
# 8     window_1_8
# 9     window_1_9
# 10   window_1_10
# 11   window_1_11
# 12   window_1_12
# 13   window_1_13
# 14   window_1_14
# 15   window_10_0
# 16   window_10_1
# 17   window_10_2
# 18   window_10_3
# 19   window_10_4
# 20   window_10_5
# 21   window_10_6
# 22   window_10_7
# 23   window_10_8
# 24   window_10_9
# 25  window_10_10
# 26  window_10_11
# 27  window_10_12
# 28  window_10_13
# 29  window_10_14
# 30   window_30_0
# 31   window_30_1
# 32   window_30_2
# 33   window_30_3
# 34   window_30_4
# 35   window_30_5
# 36   window_30_6
# 37   window_30_7
# 38   window_30_8
# 39   window_30_9
# 40  window_30_10
# 41  window_30_11
# 42  window_30_12
# 43  window_30_13
# 44  window_30_14
# 45   window_45_0
# 46   window_45_1
# 47   window_45_2
# 48   window_45_3
# 49   window_45_4
# 50   window_45_5
# ...

# %% [markdown]
# ## MASE
