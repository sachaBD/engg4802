# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv("STL_Decomposed_Irregular_data.csv")

# %%
plt.plot(data)

# %%
# Single feature LSTM or RNN
# create many features to act as predictors
# Tree based models

#

# %%
data.head()
# Out:
#     39.14
# 0  39.066
# 1  38.992
# 2  38.919
# 3  38.845
# 4  38.772

# %%
plt.plot(data[:10000])
